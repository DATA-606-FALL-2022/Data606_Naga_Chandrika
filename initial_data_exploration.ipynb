# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
CrimeAnalysis_df = pd.read_csv('Crime_Data_from_2020_to_Present.csv')
CrimeAnalysis_df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 564158  221213384  06/07/2022 12:00:00 AM  06/07/2022 12:00:00 AM      1900
# 564159  220314584  08/02/2022 12:00:00 AM  08/02/2022 12:00:00 AM        10
# 564160  221005507  02/10/2022 12:00:00 AM  02/09/2022 12:00:00 AM      1530
# 564161  221105477  02/10/2022 12:00:00 AM  02/08/2022 12:00:00 AM      2000
# 564162  221605448  02/15/2022 12:00:00 AM  02/14/2022 12:00:00 AM      1800
#
# ...

# %%
CrimeAnalysis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564163 entries, 0 to 564162
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           564163 non-null  int64
#  1   Date Rptd       564163 non-null  object
#  2   DATE OCC        564163 non-null  object
#  3   TIME OCC        564163 non-null  int64
#  4   AREA            564163 non-null  int64
#  5   AREA NAME       564163 non-null  object
#  6   Rpt Dist No     564163 non-null  int64
#  7   Part 1-2        564163 non-null  int64
#  8   Crm Cd          564163 non-null  int64
#  9   Crm Cd Desc     564163 non-null  object
#  10  Mocodes         486112 non-null  object
#  11  Vict Age        564163 non-null  int64
#  12  Vict Sex        489452 non-null  object
#  13  Vict Descent    489447 non-null  object
#  14  Premis Cd       564158 non-null  float64
#  15  Premis Desc     563904 non-null  object
# ...

# %%
CrimeAnalysis_df.describe()
# Out:
#               DR_NO       TIME OCC           AREA    Rpt Dist No  \
# count  5.641630e+05  564163.000000  564163.000000  564163.000000
# mean   2.105998e+08    1339.289431      10.743992    1120.702084
# std    7.955237e+06     654.794623       6.079010     607.903682
# min    8.170000e+02       1.000000       1.000000     101.000000
# 25%    2.015185e+08     900.000000       6.000000     625.000000
# 50%    2.109176e+08    1420.000000      11.000000    1144.000000
# 75%    2.203081e+08    1900.000000      16.000000    1619.000000
# max    2.299218e+08    2359.000000      21.000000    2199.000000
#
#             Part 1-2         Crm Cd       Vict Age      Premis Cd  \
# count  564163.000000  564163.000000  564163.000000  564158.000000
# mean        1.415174     503.385449      29.986094     301.457384
# std         0.492753     208.935535      21.691633     216.008601
# min         1.000000     110.000000      -1.000000     101.000000
# ...

# %%
CrimeAnalysis_df.isnull().sum()
# Out:
# DR_NO                  0
# Date Rptd              0
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Rpt Dist No            0
# Part 1-2               0
# Crm Cd                 0
# Crm Cd Desc            0
# Mocodes            78051
# Vict Age               0
# Vict Sex           74711
# Vict Descent       74716
# Premis Cd              5
# Premis Desc          259
# Weapon Used Cd    363785
# Weapon Desc       363785
# Status                 0
# Status Desc            0
# Crm Cd 1               6
# Crm Cd 2          520859
# Crm Cd 3          562694
# Crm Cd 4          564122
# LOCATION               0
# Cross Street      468813
# LAT                    0
# LON                    0
# dtype: int64

# %%
CrimeAnalysis_df.shape
# Out:
# (564163, 28)

# %%
CrimeAnalysis_df.dtypes
# Out:
# DR_NO               int64
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA                int64
# AREA NAME          object
# Rpt Dist No         int64
# Part 1-2            int64
# Crm Cd              int64
# Crm Cd Desc        object
# Mocodes            object
# Vict Age            int64
# Vict Sex           object
# Vict Descent       object
# Premis Cd         float64
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION           object
# Cross Street       object
# LAT               float64
# LON               float64
# dtype: object

# %%
CrimeAnalysis_df['Crm Cd Desc'].value_counts().head(15).plot.bar( figsize = (20, 10))
plt.title('Top 15 Crimes in Los Angeles', fontweight = 30, fontsize = 20)
plt.show()

# %%
CrimeAnalysis_df['AREA NAME'].value_counts().plot.bar(figsize = (20, 10))
plt.title('Total Crimes in particular area',fontsize = 30)
plt.show()

# %%
CrimeAnalysis_df['Crm Cd Desc']
# Out:
# 0                                  BATTERY - SIMPLE ASSAULT
# 1                                  BATTERY - SIMPLE ASSAULT
# 2                 SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3                  VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#                                 ...
# 564158                    INTIMATE PARTNER - SIMPLE ASSAULT
# 564159                                    THEFT OF IDENTITY
# 564160                                     VEHICLE - STOLEN
# 564161                                     VEHICLE - STOLEN
# 564162    THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# Name: Crm Cd Desc, Length: 564163, dtype: object
